# %% [markdown]
# <a href="https://colab.research.google.com/github/edanyi/ed_RCEL506/blob/main/RCEL_506_CCS_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %% [markdown]
# ## Raw GHG Data

# %% [markdown]
# ### Data Import and EDA

# %% [markdown]
# - Pull in data stored in Github
# - Understand dataframe layout and basic attributes

# %%
import pandas as pd
import numpy as np

# 2020 GHG emissions data
url1 = 'https://raw.githubusercontent.com/edanyi/ed_RCEL506/main/ghgp_data_2020.csv'
df1 = pd.read_csv(url1)

# %%
# Rows and columns
df1.shape
# Out:
# (6515, 66)

# %%
# All headings
print(list(df1.columns))
# Out:
# ['Facility Id', 'FRS Id', 'Facility Name', 'City', 'State', 'Zip Code', 'Address', 'County', 'Latitude', 'Longitude', 'Primary NAICS Code', 'Industry Type (subparts)', 'Industry Type (sectors)', 'Total reported direct emissions', 'CO2 emissions (non-biogenic)', 'Methane (CH4) emissions ', 'Nitrous Oxide (N2O) emissions ', 'HFC emissions', 'PFC emissions', 'SF6 emissions ', 'NF3 emissions', 'Other Fully Fluorinated GHG emissions', 'HFE emissions', 'Very Short-lived Compounds emissions', 'Other GHGs (metric tons CO2e)', 'Biogenic CO2 emissions (metric tons)', 'Stationary Combustion', 'Electricity Generation', 'Adipic Acid Production', 'Aluminum Production', 'Ammonia Manufacturing', 'Cement Production', 'Electronics Manufacture', 'Ferroalloy Production', 'Fluorinated GHG Production', 'Glass Production', 'HCFC22 Production from HFC23 Destruction', 'Hydrogen Production', 'Iron and Steel Production', 'Lead Production', 'Lime Production', 'Magnesium Production', 'Miscellaneous Use of Carbonates', 'Nitric Acid Production', 'Petroleum and Natural Gas Systems - Offshore Production', 'Petroleum and Natural Gas Systems - Processing', 'Petroleum and Natural Gas Systems - Transmission/Compression', 'Petroleum and Natural Gas Systems - Underground Storage', 'Petroleum and Natural Gas Systems - LNG Storage', 'Petroleum and Natural Gas Systems - LNG Import/Export', 'Petrochemical Production', 'Petroleum Refining', 'Phosphoric Acid Production', 'Pulp and Paper Manufacturing', 'Silicon Carbide Production', 'Soda Ash Manufacturing', 'Titanium Dioxide Production', 'Underground Coal Mines', 'Zinc Production', 'Municipal Landfills', 'Industrial Wastewater Treatment', 'Manufacture of Electric Transmission and Distribution Equipment', 'Industrial Waste Landfills', 'CO2 used for NH3 / Lime?', 'Supplier of CO2?', 'CEMS?']

# %%
# Data preview

df1.head(3)
# Out:
#    Facility Id        FRS Id                   Facility Name      City State  \
# 0      1004377  1.100000e+11  121 REGIONAL DISPOSAL FACILITY   MELISSA    TX
# 1      1000112  1.100000e+11                    23rd and 3rd  BROOKLYN    NY
# 2      1013621  1.100000e+11           3Bear Libby Gas Plant     Hobbs    NM
#
#    Zip Code                   Address         County  Latitude  Longitude  \
# 0     75454  3820 SAM RAYBURN HIGHWAY  COLLIN COUNTY     33.30     -96.54
# 1     11232            730 3rd Avenue          Kings     40.66     -74.00
# 2     88240           674 Marathon Rd     LEA COUNTY     32.54    -103.52
#
#    ...  Titanium Dioxide Production Underground Coal Mines Zinc Production  \
# 0  ...                          NaN                    NaN             NaN
# 1  ...                          NaN                    NaN             NaN
# 2  ...                          NaN                    NaN             NaN
#
#    Municipal Landfills  Industrial Wastewater Treatment  \
# 0             504064.0                              NaN
# 1                  NaN                              NaN
# 2                  NaN                              NaN
#
#    Manufacture of Electric Transmission and Distribution Equipment  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    Industrial Waste Landfills  CO2 used for NH3 / Lime?  Supplier of CO2?  \
# 0                         NaN                         N                 N
# 1                         NaN                         N                 N
# 2                         NaN                         N                 N
#
#    CEMS?
# 0      N
# 1      N
# 2      N
#
# [3 rows x 66 columns]

# %%
# Meta Data
# Checking for data type (int/float v. object) and missing data

df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6515 entries, 0 to 6514
# Data columns (total 66 columns):
#  #   Column                                                           Non-Null Count  Dtype
# ---  ------                                                           --------------  -----
#  0   Facility Id                                                      6515 non-null   int64
#  1   FRS Id                                                           6405 non-null   float64
#  2   Facility Name                                                    6515 non-null   object
#  3   City                                                             6515 non-null   object
#  4   State                                                            6515 non-null   object
#  5   Zip Code                                                         6515 non-null   int64
#  6   Address                                                          6038 non-null   object
#  7   County                                                           6261 non-null   object
#  8   Latitude                                                         6515 non-null   float64
#  9   Longitude                                                        6515 non-null   float64
#  10  Primary NAICS Code                                               6515 non-null   int64
#  11  Industry Type (subparts)                                         6515 non-null   object
#  12  Industry Type (sectors)                                          6515 non-null   object
#  13  Total reported direct emissions                                  6515 non-null   float64
#  14  CO2 emissions (non-biogenic)                                     5858 non-null   float64
#  15  Methane (CH4) emissions                                          6413 non-null   float64
#  16  Nitrous Oxide (N2O) emissions                                    5448 non-null   float64
#  17  HFC emissions                                                    64 non-null     float64
#  18  PFC emissions                                                    62 non-null     float64
#  19  SF6 emissions                                                    62 non-null     float64
#  20  NF3 emissions                                                    44 non-null     float64
#  21  Other Fully Fluorinated GHG emissions                            47 non-null     float64
#  22  HFE emissions                                                    22 non-null     float64
#  23  Very Short-lived Compounds emissions                             27 non-null     float64
#  24  Other GHGs (metric tons CO2e)                                    7 non-null      float64
#  25  Biogenic CO2 emissions (metric tons)                             564 non-null    float64
#  26  Stationary Combustion                                            5463 non-null   float64
#  27  Electricity Generation                                           1106 non-null   float64
#  28  Adipic Acid Production                                           2 non-null      float64
#  29  Aluminum Production                                              7 non-null      float64
#  30  Ammonia Manufacturing                                            29 non-null     float64
#  31  Cement Production                                                92 non-null     float64
#  32  Electronics Manufacture                                          48 non-null     float64
#  33  Ferroalloy Production                                            9 non-null      float64
#  34  Fluorinated GHG Production                                       15 non-null     float64
#  35  Glass Production                                                 101 non-null    float64
#  36  HCFC22 Production from HFC23 Destruction                         5 non-null      float64
#  37  Hydrogen Production                                              114 non-null    float64
#  38  Iron and Steel Production                                        122 non-null    float64
#  39  Lead Production                                                  11 non-null     float64
#  40  Lime Production                                                  71 non-null     float64
#  41  Magnesium Production                                             9 non-null      float64
#  42  Miscellaneous Use of Carbonates                                  6 non-null      float64
#  43  Nitric Acid Production                                           32 non-null     float64
#  44  Petroleum and Natural Gas Systems - Offshore Production          134 non-null    float64
#  45  Petroleum and Natural Gas Systems - Processing                   446 non-null    float64
#  46  Petroleum and Natural Gas Systems - Transmission/Compression     626 non-null    float64
#  47  Petroleum and Natural Gas Systems - Underground Storage          36 non-null     float64
#  48  Petroleum and Natural Gas Systems - LNG Storage                  5 non-null      float64
#  49  Petroleum and Natural Gas Systems - LNG Import/Export            11 non-null     float64
#  50  Petrochemical Production                                         72 non-null     float64
#  51  Petroleum Refining                                               140 non-null    float64
#  52  Phosphoric Acid Production                                       9 non-null      float64
#  53  Pulp and Paper Manufacturing                                     103 non-null    float64
#  54  Silicon Carbide Production                                       1 non-null      float64
#  55  Soda Ash Manufacturing                                           4 non-null      float64
#  56  Titanium Dioxide Production                                      6 non-null      float64
#  57  Underground Coal Mines                                           71 non-null     float64
#  58  Zinc Production                                                  5 non-null      float64
#  59  Municipal Landfills                                              1123 non-null   float64
#  60  Industrial Wastewater Treatment                                  124 non-null    float64
#  61  Manufacture of Electric Transmission and Distribution Equipment  5 non-null      float64
#  62  Industrial Waste Landfills                                       166 non-null    float64
#  63  CO2 used for NH3 / Lime?                                         6515 non-null   object
#  64  Supplier of CO2?                                                 6515 non-null   object
#  65  CEMS?                                                            6515 non-null   object
# dtypes: float64(53), int64(3), object(10)
# memory usage: 3.3+ MB

# %% [markdown]
# ### Data Cleaning

# %% [markdown]
# - Removing columns not relevant to analysis
# - Separating into two dataframes - Facility Summary and Industry Emissions Summary
#   - ***Facility Summary***: facility name/ID, state/city, latitude/longitude, regulation subparts, industry type, CO2e (including biogenic)
#   - ***Industry Emissions Summary***: emissions by process/industry, checks for utilization and injection of CO2

# %% [markdown]
# #### Facility Summary

# %%
# Create new df for summary of site information

facilities=df1.iloc[:,[2,3,4,5,8,9,11,12,13,14,25]]
facilities.index=df1['Facility Id']
facilities.head(3)
# Out:
#                               Facility Name      City State  Zip Code  \
# Facility Id
# 1004377      121 REGIONAL DISPOSAL FACILITY   MELISSA    TX     75454
# 1000112                        23rd and 3rd  BROOKLYN    NY     11232
# 1013621               3Bear Libby Gas Plant     Hobbs    NM     88240
#
#              Latitude  Longitude Industry Type (subparts)  \
# Facility Id
# 1004377         33.30     -96.54                       HH
# 1000112         40.66     -74.00                      C,D
# 1013621         32.54    -103.52                 C,W-PROC
#
#                        Industry Type (sectors)  \
# Facility Id
# 1004377                                  Waste
# 1000112                           Power Plants
# 1013621      Petroleum and Natural Gas Systems
#
#              Total reported direct emissions  CO2 emissions (non-biogenic)  \
# Facility Id
# 1004377                            504064.00                           NaN
# 1000112                             60819.70                       60751.2
# 1013621                             40521.81                       39555.5
#
#              Biogenic CO2 emissions (metric tons)
# Facility Id
# 1004377                                       NaN
# 1000112                                       NaN
# 1013621                                       NaN

# %%
# Checking if all data is present
# Exceptions - facilities with non-CO2 GHG emissions only (e.g. refrigerants)
# Exception - facilities with some or all CO2 emissions as biogenic

facilities.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6515 entries, 1004377 to 1011696
# Data columns (total 11 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Facility Name                         6515 non-null   object
#  1   City                                  6515 non-null   object
#  2   State                                 6515 non-null   object
#  3   Zip Code                              6515 non-null   int64
#  4   Latitude                              6515 non-null   float64
#  5   Longitude                             6515 non-null   float64
#  6   Industry Type (subparts)              6515 non-null   object
#  7   Industry Type (sectors)               6515 non-null   object
#  8   Total reported direct emissions       6515 non-null   float64
#  9   CO2 emissions (non-biogenic)          5858 non-null   float64
#  10  Biogenic CO2 emissions (metric tons)  564 non-null    float64
# dtypes: float64(5), int64(1), object(5)
# memory usage: 610.8+ KB

# %%
# Exclude all sources reporting only non-CO2 GHGs (e.g. CH4, refrigerants, etc) 
# For each source, check if either biogenic or non-biogenic column has a value
# Only keep the sources that satisfy this condition - np.logical_or()

biogenic=facilities['Biogenic CO2 emissions (metric tons)'].notna()
non_biogenic=facilities['CO2 emissions (non-biogenic)'].notna()
co2_filter = np.logical_or(biogenic,non_biogenic)
co2_facilities = facilities[co2_filter]

# %%
# 5896 sources are applicable for this project
# 564 sources with some amount of biogenic CO2
# 38 sources with only biogenic CO2

co2_facilities.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5896 entries, 1000112 to 1011696
# Data columns (total 11 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Facility Name                         5896 non-null   object
#  1   City                                  5896 non-null   object
#  2   State                                 5896 non-null   object
#  3   Zip Code                              5896 non-null   int64
#  4   Latitude                              5896 non-null   float64
#  5   Longitude                             5896 non-null   float64
#  6   Industry Type (subparts)              5896 non-null   object
#  7   Industry Type (sectors)               5896 non-null   object
#  8   Total reported direct emissions       5896 non-null   float64
#  9   CO2 emissions (non-biogenic)          5858 non-null   float64
#  10  Biogenic CO2 emissions (metric tons)  564 non-null    float64
# dtypes: float64(5), int64(1), object(5)
# memory usage: 552.8+ KB

# %%
# Facilities not considered
# 5896 + 619 = 6515 total sources (as in original dataframe)

missing_non_bio=facilities['CO2 emissions (non-biogenic)'].isna()     # no value
missing_bio=facilities['Biogenic CO2 emissions (metric tons)'].isna() # no value
filter = np.logical_and(missing_non_bio,missing_bio)
non_co2_facilities = facilities[filter]
non_co2_facilities.shape
# Out:
# (619, 11)

# %% [markdown]
# #### Industry Emissions Summary
# - Creating dataframe for industrial sector emissions from each facility
# - Facility may be reporting under multiple industrial sectors (i.e. subparts)

# %%
# Create new df for emissions data by industrial sector
# Include non-biogenic & biogenic data columns to allow for filtering

emissions = df1.loc[:,['CO2 emissions (non-biogenic)','Biogenic CO2 emissions (metric tons)']]
emissions.index = df1['Facility Id']
sectors = df1.iloc[:,26:]
sectors.index = df1['Facility Id']
industries = pd.concat([emissions,sectors],axis=1) # concatenate df's together
industries.shape
# Out:
# (6515, 42)

# %%
# Exclude all sources reporting only non-CO2 GHGs (e.g. CH4, refrigerants, etc) 
# For each source, check if either biogenic or non-biogenic column has a value
# Only keep the sources that satisfy this condition - np.logical_or()

biogenic=industries['Biogenic CO2 emissions (metric tons)'].notna()
non_biogenic=industries['CO2 emissions (non-biogenic)'].notna()
co2_filter = np.logical_or(biogenic,non_biogenic)
co2_industries = industries[co2_filter]

# Drop non-biogenic & biogenic data columns

co2_industries=co2_industries.drop(columns=['Biogenic CO2 emissions (metric tons)',
                                            'CO2 emissions (non-biogenic)'])
co2_industries.head(3)
# Out:
#              Stationary Combustion  Electricity Generation  \
# Facility Id
# 1000112                     199.10                 60620.6
# 1013621                   29729.99                     NaN
# 1003742                     335.45                     NaN
#
#              Adipic Acid Production  Aluminum Production  \
# Facility Id
# 1000112                         NaN                  NaN
# 1013621                         NaN                  NaN
# 1003742                         NaN                  NaN
#
#              Ammonia Manufacturing  Cement Production  \
# Facility Id
# 1000112                        NaN                NaN
# 1013621                        NaN                NaN
# 1003742                        NaN                NaN
#
#              Electronics Manufacture  Ferroalloy Production  \
# Facility Id
# 1000112                          NaN                    NaN
# 1013621                          NaN                    NaN
# 1003742                          NaN                    NaN
#
#              Fluorinated GHG Production  Glass Production  ...  \
# Facility Id                                                ...
# 1000112                             NaN               NaN  ...
# 1013621                             NaN               NaN  ...
# 1003742                             NaN               NaN  ...
#
#              Titanium Dioxide Production  Underground Coal Mines  \
# Facility Id
# 1000112                              NaN                     NaN
# 1013621                              NaN                     NaN
# 1003742                              NaN                     NaN
#
#              Zinc Production  Municipal Landfills  \
# Facility Id
# 1000112                  NaN                  NaN
# 1013621                  NaN                  NaN
# 1003742                  NaN             100165.5
#
#              Industrial Wastewater Treatment  \
# Facility Id
# 1000112                                  NaN
# 1013621                                  NaN
# 1003742                                  NaN
#
#              Manufacture of Electric Transmission and Distribution Equipment  \
# Facility Id
# 1000112                                                    NaN
# 1013621                                                    NaN
# 1003742                                                    NaN
#
#              Industrial Waste Landfills  CO2 used for NH3 / Lime?  \
# Facility Id
# 1000112                             NaN                         N
# 1013621                             NaN                         N
# 1003742                             NaN                         N
#
#              Supplier of CO2?  CEMS?
# Facility Id
# 1000112                     N      N
# 1013621                     N      N
# 1003742                     N      N
#
# [3 rows x 40 columns]

# %% [markdown]
# ## Regulatory Subpart Data

# %% [markdown]
# ### Data Import and EDA

# %% [markdown]
# - Pull in data stored in Github
# - Understand dataframe layout and basic attributes

# %%
import pandas as pd
import numpy as np

# Regulatory subparts for each industry

url2 = 'https://raw.githubusercontent.com/edanyi/ed_RCEL506/main/ghgp_industries.csv'
df2 = pd.read_csv(url2)

# %%
# Setting index as the regulatory subpart letter

df2.index = df2['Subpart Letter']
subparts = df2.loc[:,['Name of industry','Facility Type']]
subparts.head(3)
# Out:
#                       Name of industry   Facility Type
# Subpart Letter
# C                Stationary Combustion  Direct Emitter
# D               Electricity Generation  Direct Emitter
# E               Adipic Acid Production  Direct Emitter

# %%
# Checking if all data is present

subparts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 56 entries, C to UU
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Name of industry  56 non-null     object
#  1   Facility Type     56 non-null     object
# dtypes: object(2)
# memory usage: 1.3+ KB

# %% [markdown]
# ## Clean Data Summary

# %% [markdown]
# - 3 dataframes are generated to summarize the data for this analysis
#   - ***co2_facilities***: all US industrial facilities that emit CO2 emissions (2020 data)
#   - ***subparts***: correlates EPA GHG reporting program regulatory subpart (CFR Part 98) to each type of industry
#   - ***co2_industries***: CO2 emissions for each facility, broken down by regulatory subpart (i.e. industry)

# %%
co2_facilities.head(3)
# Out:
#                      Facility Name         City State  Zip Code  Latitude  \
# Facility Id
# 1000112               23rd and 3rd     BROOKLYN    NY     11232     40.66
# 1013621      3Bear Libby Gas Plant        Hobbs    NM     88240     32.54
# 1003742       31st Street Landfill  WESTCHESTER    IL     60154     41.84
#
#              Longitude Industry Type (subparts)  \
# Facility Id
# 1000112         -74.00                      C,D
# 1013621        -103.52                 C,W-PROC
# 1003742         -87.92                     C,HH
#
#                        Industry Type (sectors)  \
# Facility Id
# 1000112                           Power Plants
# 1013621      Petroleum and Natural Gas Systems
# 1003742                                  Waste
#
#              Total reported direct emissions  CO2 emissions (non-biogenic)  \
# Facility Id
# 1000112                             60819.70                       60751.2
# 1013621                             40521.81                       39555.5
# 1003742                            100500.95                         334.9
#
#              Biogenic CO2 emissions (metric tons)
# Facility Id
# 1000112                                       NaN
# 1013621                                       NaN
# 1003742                                       NaN

# %%
subparts.head(3)
# Out:
#                       Name of industry   Facility Type
# Subpart Letter
# C                Stationary Combustion  Direct Emitter
# D               Electricity Generation  Direct Emitter
# E               Adipic Acid Production  Direct Emitter

# %%
co2_industries.head(3)
# Out:
#              Stationary Combustion  Electricity Generation  \
# Facility Id
# 1000112                     199.10                 60620.6
# 1013621                   29729.99                     NaN
# 1003742                     335.45                     NaN
#
#              Adipic Acid Production  Aluminum Production  \
# Facility Id
# 1000112                         NaN                  NaN
# 1013621                         NaN                  NaN
# 1003742                         NaN                  NaN
#
#              Ammonia Manufacturing  Cement Production  \
# Facility Id
# 1000112                        NaN                NaN
# 1013621                        NaN                NaN
# 1003742                        NaN                NaN
#
#              Electronics Manufacture  Ferroalloy Production  \
# Facility Id
# 1000112                          NaN                    NaN
# 1013621                          NaN                    NaN
# 1003742                          NaN                    NaN
#
#              Fluorinated GHG Production  Glass Production  ...  \
# Facility Id                                                ...
# 1000112                             NaN               NaN  ...
# 1013621                             NaN               NaN  ...
# 1003742                             NaN               NaN  ...
#
#              Titanium Dioxide Production  Underground Coal Mines  \
# Facility Id
# 1000112                              NaN                     NaN
# 1013621                              NaN                     NaN
# 1003742                              NaN                     NaN
#
#              Zinc Production  Municipal Landfills  \
# Facility Id
# 1000112                  NaN                  NaN
# 1013621                  NaN                  NaN
# 1003742                  NaN             100165.5
#
#              Industrial Wastewater Treatment  \
# Facility Id
# 1000112                                  NaN
# 1013621                                  NaN
# 1003742                                  NaN
#
#              Manufacture of Electric Transmission and Distribution Equipment  \
# Facility Id
# 1000112                                                    NaN
# 1013621                                                    NaN
# 1003742                                                    NaN
#
#              Industrial Waste Landfills  CO2 used for NH3 / Lime?  \
# Facility Id
# 1000112                             NaN                         N
# 1013621                             NaN                         N
# 1003742                             NaN                         N
#
#              Supplier of CO2?  CEMS?
# Facility Id
# 1000112                     N      N
# 1013621                     N      N
# 1003742                     N      N
#
# [3 rows x 40 columns]

# %% [markdown]
# # Industry Summaries

# %% [markdown]
# - Categorizing facilities by industry
# - Perform basic statistics on each industrial sector
# - Primary focus on the following industries (*priority_industries*):
#   - Electricity Generation (Coal Power/Natural Gas)
#   - Petroleum and Natural Gas Systems - Processing
#   - Ethanol (*not reported because biogenic*)
#   - Ammonia Manufacturing
#   - Hydrogen Production
#   - Cement Production
#   - Petroleum Refining (FCC)
#   - Iron and Steel Production
#   - Stationary Combustion (Industrial Furnaces)

# %%
# Number of industries
# Last two columns are not industries

co2_industries.columns[:-3].nunique()
# Out:
# 37

# %%
# Sum of facilities in each industry
# If missing value, facility does not belong to that industry/subpart

co2_industries.notna().sum()
# Out:
# Stationary Combustion                                              5463
# Electricity Generation                                             1106
# Adipic Acid Production                                                2
# Aluminum Production                                                   7
# Ammonia Manufacturing                                                29
# Cement Production                                                    92
# Electronics Manufacture                                              48
# Ferroalloy Production                                                 9
# Fluorinated GHG Production                                           14
# Glass Production                                                    101
# HCFC22 Production from HFC23 Destruction                              5
# Hydrogen Production                                                 114
# Iron and Steel Production                                           122
# Lead Production                                                      11
# Lime Production                                                      71
# Magnesium Production                                                  6
# Miscellaneous Use of Carbonates                                       6
# Nitric Acid Production                                               31
# Petroleum and Natural Gas Systems - Offshore Production             134
# Petroleum and Natural Gas Systems - Processing                      446
# Petroleum and Natural Gas Systems - Transmission/Compression        626
# Petroleum and Natural Gas Systems - Underground Storage              36
# Petroleum and Natural Gas Systems - LNG Storage                       5
# Petroleum and Natural Gas Systems - LNG Import/Export                11
# Petrochemical Production                                             72
# Petroleum Refining                                                  140
# Phosphoric Acid Production                                            9
# Pulp and Paper Manufacturing                                        103
# Silicon Carbide Production                                            1
# Soda Ash Manufacturing                                                4
# Titanium Dioxide Production                                           6
# Underground Coal Mines                                               28
# Zinc Production                                                       5
# Municipal Landfills                                                 574
# Industrial Wastewater Treatment                                     121
# Manufacture of Electric Transmission and Distribution Equipment       3
# Industrial Waste Landfills                                          149
# CO2 used for NH3 / Lime?                                           5896
# Supplier of CO2?                                                   5896
# CEMS?                                                              5896
# dtype: int64

# %%
# Basic statistics for each industry
# Note - the cells without values are not counted

co2_industries['Electricity Generation'].describe()
# Out:
# count    1.106000e+03
# mean     1.300664e+06
# std      2.077510e+06
# min      0.000000e+00
# 25%      7.077331e+04
# 50%      4.635323e+05
# 75%      1.617321e+06
# max      1.723290e+07
# Name: Electricity Generation, dtype: float64

# %%
# Function to plot histogram for one industrial sectors

def histogram(header):

  import seaborn as sns
  import matplotlib.pyplot as plt

  fig, ax = plt.subplots()
  sns.histplot(data=co2_industries[header])
  ax.set_xlabel("CO2 Emissions (mtpa)")
  ax.set_ylabel("# of Facilities",rotation=0,labelpad=45)
  ax.set_title(header)

# %%
histogram('Cement Production')

# %%
# Only considering priority industries

priority_industries = co2_industries.iloc[:,[0,1,4,5,11,12,19,25]]

for labels,content in priority_industries.items():
  histogram(labels)

# %%
  # Why doesn't box plot show?

  import matplotlib.pyplot as plt

  fig, ax = plt.subplots()
  ax.boxplot(priority_industries['Cement Production'])
  ax.set_xlabel("CO2 Emissions")
  ax.set_ylabel("# of Facilities",rotation=0,labelpad=45)
  ax.set_title('title')
  plt.show()

# %% [markdown]
# # Facility Classification

# %% [markdown]
# - Classify each facility into it's respective industrial sectors (i.e. based on regulatory subpart)
#   - Extract values from 'Industry Type (subparts)' columns
#   - Sort individual subparts into separate new columns in the dataframe
#   - Correlate subpart(s) to industry type(s) using *subparts( )* dataframe

# %%
co2_facilities.loc[:,'Industry Type (subparts)']
# Out:
# Facility Id
# 1000112         C,D
# 1013621    C,W-PROC
# 1003742        C,HH
# 1003188         C,N
# 1005043           C
#              ...
# 1010592    C,W-PROC
# 1000805         C,D
# 1001464           D
# 1012625         C,Q
# 1011696        C,HH
# Name: Industry Type (subparts), Length: 5896, dtype: object

# %%
# For each row, test splitting element contents separated by a comma

co2_facilities.loc[1013621,'Industry Type (subparts)'].split(',')
# Out:
# ['C', 'W-PROC']

# %%
# To determine individual subparts for each facility,
# First count number of individual subparts for each facility
# Create new column in dataframe to hold the total subparts per facility
# New column equals the old column with lambda function applied
# lambda syntax = variables:operations 
# Determine length of string created by the split function

co2_facilities['# of Subparts']=co2_facilities['Industry Type (subparts)'].apply(lambda x:len(x.split(',')))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Function to split element contents separated by a comma
# For each element, use an index to count each subpart
# Once # of subparts exceeds the index, function returns nan 

def splitter(value,index):
  try:
    return value.split(',')[index]
  except:
    return np.nan

# %%
# Test - facility 1013621 has two subparts (index = 0,1,nan,...)

splitter(co2_facilities.loc[1013621,'Industry Type (subparts)'],1)
# Out:
# 'W-PROC'

# %%
# Create new column for first subpart of each facility (index = 0)
# New column equals the old column with lambda function applied
# Lambda function uses splitter() function to split element and select indexed item in list

co2_facilities['Subpart 1']=co2_facilities['Industry Type (subparts)'].apply(lambda x:splitter(x,0))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
# Test - new column created, containing only first subpart in the list

co2_facilities['Subpart 1']
# Out:
# Facility Id
# 1000112    C
# 1013621    C
# 1003742    C
# 1003188    C
# 1005043    C
#           ..
# 1010592    C
# 1000805    C
# 1001464    D
# 1012625    C
# 1011696    C
# Name: Subpart 1, Length: 5896, dtype: object

# %%
# For the entire column, testing the maximum number of subparts for a facility

co2_facilities['# of Subparts'].max()
# Out:
# 6

# %%
# Loop to create 6 columns (maximum number of subparts for a given facility)

for n in range(1,7):
  co2_facilities['Subpart '+str(n)]=co2_facilities['Industry Type (subparts)'].apply(lambda x:splitter(x,n-1))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
co2_facilities.head(3)
# Out:
#                      Facility Name         City State  Zip Code  Latitude  \
# Facility Id
# 1000112               23rd and 3rd     BROOKLYN    NY     11232     40.66
# 1013621      3Bear Libby Gas Plant        Hobbs    NM     88240     32.54
# 1003742       31st Street Landfill  WESTCHESTER    IL     60154     41.84
#
#              Longitude Industry Type (subparts)  \
# Facility Id
# 1000112         -74.00                      C,D
# 1013621        -103.52                 C,W-PROC
# 1003742         -87.92                     C,HH
#
#                        Industry Type (sectors)  \
# Facility Id
# 1000112                           Power Plants
# 1013621      Petroleum and Natural Gas Systems
# 1003742                                  Waste
#
#              Total reported direct emissions  CO2 emissions (non-biogenic)  \
# Facility Id
# 1000112                             60819.70                       60751.2
# 1013621                             40521.81                       39555.5
# 1003742                            100500.95                         334.9
#
#              Biogenic CO2 emissions (metric tons)  # of Subparts Subpart 1  \
# Facility Id
# 1000112                                       NaN              2         C
# 1013621                                       NaN              2         C
# 1003742                                       NaN              2         C
#
#             Subpart 2 Subpart 3 Subpart 4 Subpart 5 Subpart 6
# Facility Id
# 1000112             D       NaN       NaN       NaN       NaN
# 1013621        W-PROC       NaN       NaN       NaN       NaN
# 1003742            HH       NaN       NaN       NaN       NaN

# %%
# Looking to swap Subpart letter in co2_facilities with industry name

subparts[['Name of industry']]
# Out:
#                                                  Name of industry
# Subpart Letter
# C                                           Stationary Combustion
# D                                          Electricity Generation
# E                                          Adipic Acid Production
# F                                             Aluminum Production
# G                                           Ammonia Manufacturing
# H                                               Cement Production
# I                                         Electronics Manufacture
# K                                           Ferroalloy Production
# L                                      Fluorinated GHG Production
# N                                                Glass Production
# O                       HCFC-22 Production and HFC-23 Destruction
# P                                             Hydrogen Production
# Q                                       Iron and Steel Production
# R                                                 Lead Production
# S                                                 Lime Production
# T                                            Magnesium Production
# U                                 Miscellaneous Use of Carbonates
# V                                          Nitric Acid Production
# W                               Petroleum and Natural Gas Systems
# W-OFFSH         Petroleum and Natural Gas Systems-Offshore Pro...
# W-ONSH          Petroleum and Natural Gas Systems-Onshore Prod...
# W-GB            Petroleum and Nautral Gas Systems-Gathering an...
# W-PROC          Petroleum and Natural Gas Systems-Natural Gas ...
# W-NGTC          Petroleum and Natural Gas Systems-Natural Gas ...
# W-TRANS         Petroleum and Natural Gas Systems-Transmission...
# W-UNSTG         Petroleum and Natural Gas Systems-Underground ...
# W-LNGSTG        Petroleum and Natural Gas Systems-Liquified Na...
# W-LNGIE         Petroleum and Natural Gas Systems-Liquified Na...
# W-LDC           Petroleum and Natural Gas Systems-Natural Gas ...
# X                                        Petrochemical Production
# Y                                              Petroleum Refining
# Z                                      Phosphoric Acid Production
# AA                                   Pulp and Paper Manufacturing
# BB                                     Silicon Carbide Production
# CC                                         Soda Ash Manufacturing
# DD                                  SF6 from Electrical Equipment
# EE                                    Titanium Dioxide Production
# FF                                         Underground Coal Mines
# GG                                                Zinc Production
# HH                                            Municipal Landfills
# II                                Industrial Wastewater Treatment
# LL                          Suppliers of Coal Based Liquids Fuels
# MM                                Suppliers of Petroleum Products
# MM-REF                              Petroleum Refinery (Producer)
# MM-IMP                                 Petroleum Product Importer
# MM-EXP                                 Petroleum Product Exporter
# NN                      Natural Gas and Natural Gas Liquid Supply
# NN-FRAC                          Natural Gas Liquids Fractionator
# NN-LDC            Natural Gas Local Distribution Company (supply)
# OO                                  Non-CO2 Industrial Gas Supply
# PP                                    Carbon Dioxide (CO2) Supply
# QQ              Import and Export of Equipment Containing Fluo...
# RR                       Geologic Sequestration of Carbon Dioxide
# SS              Manufacture of Electric Transmission and Distr...
# TT                                     Industrial Waste Landfills
# UU                                    Injection of Carbon Dioxide
